# %%
import pandas as pd
from pathlib import Path

# Work out the project root (same trick as the other notebook)
cwd = Path.cwd()
BASE_DIR = cwd.parent if cwd.name.lower() == "notebooks" else cwd

csv_path = BASE_DIR / "data" / "kaggle_voice_phish.csv"

print("Project root:", BASE_DIR)
print("Kaggle CSV path:", csv_path)
print("File exists?", csv_path.exists())

# Read the CSV
df = pd.read_csv(csv_path)

print("\n=== Columns in Kaggle dataset ===")
print(df.columns.tolist())

print("\n=== First 5 rows ===")
print(df.head())
